# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\Saurav\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Saurav\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
dataset=pd.read_csv('Mall_Customers.csv')

# %%
x=dataset.iloc[:,[3,4]].values
import scipy.cluster.hierarchy as h
d=h.dendrogram(h.linkage(x,method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cl=AgglomerativeClustering(n_clusters=5,linkage='ward',affinity='euclidean')
y=cl.fit_predict(x)

# %%
plt.scatter(x[y==0,0],x[y==0,1],s=60,color='red')
plt.scatter(x[y==1,0],x[y==1,1],s=60,color='blue')
plt.scatter(x[y==2,0],x[y==2,1],s=60,color='yellow')
plt.scatter(x[y==3,0],x[y==3,1],s=60,color='cyan')
plt.scatter(x[y==4,0],x[y==4,1],s=60,color='magenta')
